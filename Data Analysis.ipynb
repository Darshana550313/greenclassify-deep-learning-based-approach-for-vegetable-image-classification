# %%
import os

# %%
train_path  = r"C:\Users\Admin\OneDrive\Desktop\Greenclassify\dataset\Vegetable Images"
classes = os.listdir(train_path)
print("Vegetable Classes:", classes)
print("Number of Classes:", len(classes))
# Out:
# Vegetable Classes: ['test', 'train', 'validation']
# Number of Classes: 3

# %%
for veg in classes:
    count = len(os.listdir(os.path.join(train_path, veg)))
    print(f"{veg} → {count} images")
# Out:
# test → 15 images
# train → 15 images
# validation → 15 images
